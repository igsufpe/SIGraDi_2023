# %% [markdown]
# #SIGRADI 2023#
#
# #Aprendizagem de máquina aplicada na avaliação de projetos aeroportuários no Brasil baseados em modelos BIM#
#
#
# Autores:
# *   Ítalo Guedes dos Santos¹ – italo.guedes@ufpe.br
# *   Max Andrade¹ - max.andrade@ufpe.br
# *   Cleber Zanchettin² - cz@cin.ufpe.br
# *   Adriana Rolim³ - adriana.rolim@mpor.gov.br
#
#
# ¹ Universidade Federal de Pernambuco (UFPE), ² Centro de Informática Universidade Federal de Pernambuco (CIn / UFPE), ³ Secretaria Nacional de Aviação Civil (SAC)
#
# Data: agosto / 2023

# %% [markdown]
# #Setup

# %%
import pandas as pd

# %% [markdown]
# #Dataset import (.csv)

# %%
train_df = pd.read_csv('/content/sample_data/DATASET-TPS-SIGRADI-R00-TREINO.csv',encoding="ISO-8859-1", delimiter=';')
valid_df = pd.read_csv('/content/sample_data/DATASET-TPS-SIGRADI-R00-TESTE.csv',encoding="ISO-8859-1", delimiter=';')

# %% [markdown]
# #Data visualization

# %%
train_df.head()
# Out:
#    L1  C1  L2  C2  L3  C3  L4  C4  L5  C5  ...  C11  L12  C12  L13  C13  L14  \
# 0   2   5   6  28   8   1   4   2   5   5  ...    4    8   19   23    6    3
# 1   6   5   3  16   4   4   1   3   8   5  ...    5   14   18   12    5    3
# 2   6   5   4  15   4   2   3   2   3   2  ...    8   11   19   23    3    3
# 3   3   2   5  15   7   5   3   2   6   7  ...    8    7   14    9    8    3
# 4   2   4   7  25   5   1   1   5   3   7  ...    4   14    9   25    4    2
#
#    C14  L15  C15  status
# 0    6    2   27       0
# 1    2    4   49       1
# 2    4    1   18       1
# 3    4    3   25       0
# 4    5    3    8       0
#
# [5 rows x 31 columns]

# %% [markdown]
# #Separating the response variable

# %%
y_train = train_df['status']
y_valid = valid_df['status']
del train_df['status']
del valid_df['status']

# %%
y_train[0:10]
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    0
# 5    0
# 6    0
# 7    1
# 8    0
# 9    0
# Name: status, dtype: int64

# %%
train_df.head()
# Out:
#    L1  C1  L2  C2  L3  C3  L4  C4  L5  C5  ...  L11  C11  L12  C12  L13  C13  \
# 0   2   5   6  28   8   1   4   2   5   5  ...    5    4    8   19   23    6
# 1   6   5   3  16   4   4   1   3   8   5  ...    6    5   14   18   12    5
# 2   6   5   4  15   4   2   3   2   3   2  ...    6    8   11   19   23    3
# 3   3   2   5  15   7   5   3   2   6   7  ...    4    8    7   14    9    8
# 4   2   4   7  25   5   1   1   5   3   7  ...    2    4   14    9   25    4
#
#    L14  C14  L15  C15
# 0    3    6    2   27
# 1    3    2    4   49
# 2    3    4    1   18
# 3    3    4    3   25
# 4    2    5    3    8
#
# [5 rows x 30 columns]

# %% [markdown]
# #Creating training /test set

# %%
x_train = train_df.values
x_valid = valid_df.values

# %%
x_train[0]
# Out:
# array([ 2,  5,  6, 28,  8,  1,  4,  2,  5,  5,  9,  5,  1,  6, 20,  5,  3,
#        12, 12, 12,  5,  4,  8, 19, 23,  6,  3,  6,  2, 27])

# %% [markdown]
# # Summarizing the Training and Validation Data

# %%
x_train.shape
# Out:
# (800, 30)

# %%
y_train.shape
# Out:
# (800,)

# %%
x_valid.shape
# Out:
# (200, 30)

# %%
y_valid.shape
# Out:
# (200,)

# %%
x_train.min()
# Out:
# 1

# %%
x_train.max()
# Out:
# 54

# %% [markdown]
# #Normalize x_train and x_valid

# %%
x_train = x_train / 54
x_valid = x_valid / 54

# %%
x_train.min()
# Out:
# 0.018518518518518517

# %%
x_train.max()
# Out:
# 1.0

# %% [markdown]
# #Import TabNet (Deep Neural Network)

# %%
# !pip install pytorch_tabnet
# Out:
# Requirement already satisfied: pytorch_tabnet in /usr/local/lib/python3.10/dist-packages (4.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (1.23.5)
# Requirement already satisfied: scikit_learn>0.21 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (1.2.2)
# Requirement already satisfied: scipy>1.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (1.10.1)
# Requirement already satisfied: torch>=1.3 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.36 in /usr/local/lib/python3.10/dist-packages (from pytorch_tabnet) (4.66.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit_learn>0.21->pytorch_tabnet) (3.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (3.12.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (4.7.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.3->pytorch_tabnet) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3->pytorch_tabnet) (3.27.1)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.3->pytorch_tabnet) (16.0.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.3->pytorch_tabnet) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.3->pytorch_tabnet) (1.3.0)

# %% [markdown]
# ## Summarizing the Model

# %%
from pytorch_tabnet.tab_model import TabNetClassifier
import torch

# %% [markdown]
# ## Defining the Model

# %%
clf= TabNetClassifier(optimizer_fn=torch.optim.Adam,
                       scheduler_params={"step_size":10,
                                         "gamma":0.9},
                       scheduler_fn=torch.optim.lr_scheduler.StepLR,
                      )
# Out:
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/abstract_model.py:82: UserWarning: Device used : cpu
#   warnings.warn(f"Device used : {self.device}")

# %% [markdown]
# ##Train the Model

# %%
clf.fit(
    x_train,y_train,
    eval_set=[(x_train, y_train), (x_valid, y_valid)],
    eval_name=['train', 'valid'],
    eval_metric=['auc','balanced_accuracy'],
    max_epochs=200, patience=60,
    batch_size=512, virtual_batch_size=512,
    num_workers=0,
    weights=1,
    drop_last=False
)
# Out:
# epoch 0  | loss: 0.79994 | train_auc: 0.49309 | train_balanced_accuracy: 0.50797 | valid_auc: 0.50705 | valid_balanced_accuracy: 0.4895  |  0:00:00s
# epoch 1  | loss: 0.73207 | train_auc: 0.51385 | train_balanced_accuracy: 0.5     | valid_auc: 0.54505 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 2  | loss: 0.64193 | train_auc: 0.53823 | train_balanced_accuracy: 0.5     | valid_auc: 0.56616 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 3  | loss: 0.6062  | train_auc: 0.53728 | train_balanced_accuracy: 0.5     | valid_auc: 0.59036 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 4  | loss: 0.6256  | train_auc: 0.55509 | train_balanced_accuracy: 0.50041 | valid_auc: 0.59098 | valid_balanced_accuracy: 0.49825 |  0:00:00s
# epoch 5  | loss: 0.57788 | train_auc: 0.57539 | train_balanced_accuracy: 0.55091 | valid_auc: 0.60416 | valid_balanced_accuracy: 0.53378 |  0:00:00s
# epoch 6  | loss: 0.53997 | train_auc: 0.60368 | train_balanced_accuracy: 0.53503 | valid_auc: 0.67727 | valid_balanced_accuracy: 0.57095 |  0:00:00s
# epoch 7  | loss: 0.51504 | train_auc: 0.60331 | train_balanced_accuracy: 0.51722 | valid_auc: 0.70158 | valid_balanced_accuracy: 0.55092 |  0:00:00s
# epoch 8  | loss: 0.48987 | train_auc: 0.62922 | train_balanced_accuracy: 0.5192  | valid_auc: 0.72557 | valid_balanced_accuracy: 0.57425 |  0:00:00s
# epoch 9  | loss: 0.46402 | train_auc: 0.63785 | train_balanced_accuracy: 0.61988 | valid_auc: 0.74163 | valid_balanced_accuracy: 0.66548 |  0:00:00s
# epoch 10 | loss: 0.42676 | train_auc: 0.65866 | train_balanced_accuracy: 0.5     | valid_auc: 0.75121 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 11 | loss: 0.44262 | train_auc: 0.70006 | train_balanced_accuracy: 0.5     | valid_auc: 0.76274 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 12 | loss: 0.40451 | train_auc: 0.72533 | train_balanced_accuracy: 0.5     | valid_auc: 0.75832 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 13 | loss: 0.37998 | train_auc: 0.67741 | train_balanced_accuracy: 0.5     | valid_auc: 0.63794 | valid_balanced_accuracy: 0.5     |  0:00:00s
# epoch 14 | loss: 0.33507 | train_auc: 0.61406 | train_balanced_accuracy: 0.5     | valid_auc: 0.53362 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 15 | loss: 0.33342 | train_auc: 0.58368 | train_balanced_accuracy: 0.5     | valid_auc: 0.48491 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 16 | loss: 0.31487 | train_auc: 0.56996 | train_balanced_accuracy: 0.5     | valid_auc: 0.46267 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 17 | loss: 0.30321 | train_auc: 0.56277 | train_balanced_accuracy: 0.5     | valid_auc: 0.45093 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 18 | loss: 0.26604 | train_auc: 0.56398 | train_balanced_accuracy: 0.5     | valid_auc: 0.44475 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 19 | loss: 0.27762 | train_auc: 0.57291 | train_balanced_accuracy: 0.5     | valid_auc: 0.45443 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 20 | loss: 0.27119 | train_auc: 0.59206 | train_balanced_accuracy: 0.5     | valid_auc: 0.48193 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 21 | loss: 0.26144 | train_auc: 0.6103  | train_balanced_accuracy: 0.5     | valid_auc: 0.51251 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 22 | loss: 0.21352 | train_auc: 0.63299 | train_balanced_accuracy: 0.5     | valid_auc: 0.53342 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 23 | loss: 0.23778 | train_auc: 0.67062 | train_balanced_accuracy: 0.5     | valid_auc: 0.57852 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 24 | loss: 0.20532 | train_auc: 0.71365 | train_balanced_accuracy: 0.5     | valid_auc: 0.62414 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 25 | loss: 0.2031  | train_auc: 0.75755 | train_balanced_accuracy: 0.5     | valid_auc: 0.68448 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 26 | loss: 0.20643 | train_auc: 0.78126 | train_balanced_accuracy: 0.5     | valid_auc: 0.70559 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 27 | loss: 0.16354 | train_auc: 0.77713 | train_balanced_accuracy: 0.5     | valid_auc: 0.69509 | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 28 | loss: 0.19609 | train_auc: 0.74957 | train_balanced_accuracy: 0.5     | valid_auc: 0.6575  | valid_balanced_accuracy: 0.5     |  0:00:01s
# epoch 29 | loss: 0.18485 | train_auc: 0.74011 | train_balanced_accuracy: 0.5     | valid_auc: 0.64535 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 30 | loss: 0.16748 | train_auc: 0.74642 | train_balanced_accuracy: 0.5     | valid_auc: 0.65174 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 31 | loss: 0.15438 | train_auc: 0.76785 | train_balanced_accuracy: 0.5     | valid_auc: 0.67841 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 32 | loss: 0.1511  | train_auc: 0.80681 | train_balanced_accuracy: 0.5     | valid_auc: 0.73463 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 33 | loss: 0.12126 | train_auc: 0.84022 | train_balanced_accuracy: 0.5     | valid_auc: 0.78272 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 34 | loss: 0.14332 | train_auc: 0.85553 | train_balanced_accuracy: 0.5     | valid_auc: 0.81439 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 35 | loss: 0.10833 | train_auc: 0.86007 | train_balanced_accuracy: 0.5     | valid_auc: 0.83071 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 36 | loss: 0.1031  | train_auc: 0.8647  | train_balanced_accuracy: 0.5     | valid_auc: 0.84389 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 37 | loss: 0.12503 | train_auc: 0.8665  | train_balanced_accuracy: 0.5     | valid_auc: 0.85707 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 38 | loss: 0.10235 | train_auc: 0.86363 | train_balanced_accuracy: 0.5     | valid_auc: 0.86541 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 39 | loss: 0.12685 | train_auc: 0.85874 | train_balanced_accuracy: 0.5     | valid_auc: 0.87612 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 40 | loss: 0.07248 | train_auc: 0.85734 | train_balanced_accuracy: 0.5     | valid_auc: 0.89085 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 41 | loss: 0.07574 | train_auc: 0.85882 | train_balanced_accuracy: 0.5     | valid_auc: 0.90856 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 42 | loss: 0.09093 | train_auc: 0.86416 | train_balanced_accuracy: 0.5     | valid_auc: 0.91772 | valid_balanced_accuracy: 0.5     |  0:00:02s
# epoch 43 | loss: 0.0645  | train_auc: 0.8682  | train_balanced_accuracy: 0.5     | valid_auc: 0.91824 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 44 | loss: 0.07081 | train_auc: 0.86752 | train_balanced_accuracy: 0.5     | valid_auc: 0.91278 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 45 | loss: 0.06004 | train_auc: 0.86545 | train_balanced_accuracy: 0.5     | valid_auc: 0.90825 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 46 | loss: 0.06793 | train_auc: 0.86183 | train_balanced_accuracy: 0.5     | valid_auc: 0.90784 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 47 | loss: 0.06414 | train_auc: 0.85521 | train_balanced_accuracy: 0.5     | valid_auc: 0.90434 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 48 | loss: 0.03464 | train_auc: 0.84823 | train_balanced_accuracy: 0.5     | valid_auc: 0.90166 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 49 | loss: 0.04883 | train_auc: 0.83943 | train_balanced_accuracy: 0.5     | valid_auc: 0.89682 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 50 | loss: 0.05138 | train_auc: 0.83271 | train_balanced_accuracy: 0.5     | valid_auc: 0.89342 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 51 | loss: 0.04089 | train_auc: 0.82978 | train_balanced_accuracy: 0.5     | valid_auc: 0.89435 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 52 | loss: 0.05858 | train_auc: 0.83003 | train_balanced_accuracy: 0.5     | valid_auc: 0.89646 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 53 | loss: 0.05089 | train_auc: 0.8319  | train_balanced_accuracy: 0.5     | valid_auc: 0.89682 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 54 | loss: 0.06008 | train_auc: 0.83688 | train_balanced_accuracy: 0.5     | valid_auc: 0.89651 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 55 | loss: 0.05145 | train_auc: 0.84232 | train_balanced_accuracy: 0.5     | valid_auc: 0.89831 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 56 | loss: 0.04658 | train_auc: 0.84792 | train_balanced_accuracy: 0.5     | valid_auc: 0.9031  | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 57 | loss: 0.0328  | train_auc: 0.8547  | train_balanced_accuracy: 0.5     | valid_auc: 0.90979 | valid_balanced_accuracy: 0.5     |  0:00:03s
# epoch 58 | loss: 0.04389 | train_auc: 0.85816 | train_balanced_accuracy: 0.5     | valid_auc: 0.91262 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 59 | loss: 0.03829 | train_auc: 0.8603  | train_balanced_accuracy: 0.5     | valid_auc: 0.91571 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 60 | loss: 0.06418 | train_auc: 0.86394 | train_balanced_accuracy: 0.5     | valid_auc: 0.91772 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 61 | loss: 0.05451 | train_auc: 0.86672 | train_balanced_accuracy: 0.5     | valid_auc: 0.91958 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 62 | loss: 0.04407 | train_auc: 0.86771 | train_balanced_accuracy: 0.5     | valid_auc: 0.91916 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 63 | loss: 0.04924 | train_auc: 0.86853 | train_balanced_accuracy: 0.5     | valid_auc: 0.92112 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 64 | loss: 0.03632 | train_auc: 0.86945 | train_balanced_accuracy: 0.5     | valid_auc: 0.92261 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 65 | loss: 0.042   | train_auc: 0.87129 | train_balanced_accuracy: 0.5     | valid_auc: 0.92483 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 66 | loss: 0.05544 | train_auc: 0.87409 | train_balanced_accuracy: 0.5     | valid_auc: 0.92781 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 67 | loss: 0.0287  | train_auc: 0.87919 | train_balanced_accuracy: 0.5     | valid_auc: 0.93101 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 68 | loss: 0.043   | train_auc: 0.8841  | train_balanced_accuracy: 0.5     | valid_auc: 0.93204 | valid_balanced_accuracy: 0.5     |  0:00:04s
# epoch 69 | loss: 0.03122 | train_auc: 0.88767 | train_balanced_accuracy: 0.5     | valid_auc: 0.93337 | valid_balanced_accuracy: 0.5     |  0:00:04s
#
# Early stopping occurred at epoch 69 with best_epoch = 9 and best_valid_balanced_accuracy = 0.66548
# /usr/local/lib/python3.10/dist-packages/pytorch_tabnet/callbacks.py:172: UserWarning: Best weights from best epoch are automatically used!
#   warnings.warn(wrn_msg)
